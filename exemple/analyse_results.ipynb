# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
pbound=[]
pbound.append(np.genfromtxt("t2/sin2pulse/diss/pbound.10000"))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-9f0263ee2d6e> in <module>()
#       3 get_ipython().magic('matplotlib inline')
#       4 pbound=[]
# ----> 5 pbound.append(np.genfromtxt("t2/sin2pulse/diss/pbound.10000"))
#
# /home/fradion12/.local/share/jupyter/kernels/py3_numpy/env/lib/python3.5/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows)
#    1448                 fhd = iter(np.lib._datasource.open(fname, 'rbU'))
#    1449             else:
# -> 1450                 fhd = iter(np.lib._datasource.open(fname, 'rb'))
#    1451             own_fhd = True
#    1452         else:
#
# ...

# %%
print(pbound[0][:,0])
#plt.plot(pbound[0][:,0],pbound[0][:,1])
plt.plot(pbound[0][:,0],pbound[0][:,2])
plt.plot(pbound[0][:,0],pbound[0][:,3])
plt.axis([8000,14000,-0.06,0.06])
# Out:
# [  0.00000000e+00   1.00000000e+00   2.00000000e+00 ...,   1.62890000e+04
#    1.62900000e+04   1.62910000e+04]
# [8000, 14000, -0.06, 0.06]

# %%
pbound_square=[]
pbound_square.append(np.genfromtxt("t2/diss/pbound.10000"))

# %%
plt.plot(pbound_square[0][:,0],pbound_square[0][:,2])

# %%
pbound_new=[]
pbound_new.append(np.genfromtxt("pbound.10000"))
plt.plot(pbound_new[0][:,0],pbound_new[0][:,2])
plt.plot(pbound_new[0][:,0],pbound_new[0][:,3])
plt.show()
plt.close()
plt.plot(pbound_new[0][:,0],pbound_new[0][:,1])
